# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd '/gdrive/My Drive/Extraction_organisms'
# Out:
# /gdrive/My Drive/Extraction_organisms

# %%
#! git clone https://github.com/thierrynems/gepoFeatureEngineering.git
# !pip install biopython
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 5.1 MB/s
# ...

# %%
# !python cleanFile.py
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# APO:ARCPR_1155
# APO:ARCPR_1156
# APO:ARCPR_1157
# APO:ARCPR_1158
# APO:ARCPR_1159
# APO:ARCPR_1160
# APO:ARCPR_1161
# APO:ARCPR_1162
# APO:ARCPR_1163
# APO:ARCPR_1164
# APO:ARCPR_1165
# APO:ARCPR_1167
# APO:ARCPR_1168
# APO:ARCPR_1169
# APO:ARCPR_1170
# APO:ARCPR_1171
# APO:ARCPR_1173
# APO:ARCPR_1174
# APO:ARCPR_1175
# APO:ARCPR_1176
# APO:ARCPR_1178
# APO:ARCPR_1179
# APO:ARCPR_1180
# APO:ARCPR_1181
# APO:ARCPR_1182
# APO:ARCPR_1183
# APO:ARCPR_1184
# APO:ARCPR_1185
# APO:ARCPR_1186
# APO:ARCPR_1187
# APO:ARCPR_1188
# APO:ARCPR_1189
# APO:ARCPR_1190
# APO:ARCPR_1191
# APO:ARCPR_1192
# APO:ARCPR_1193
# APO:ARCPR_1194
# APO:ARCPR_1195
# APO:ARCPR_1196
# APO:ARCPR_1197
# APO:ARCPR_1198
# APO:ARCPR_1199
# APO:ARCPR_1200
# APO:ARCPR_1201
# APO:ARCPR_1202
# APO:ARCPR_1203
# APO:ARCPR_1204
# APO:ARCPR_1205
# APO:ARCPR_1206
# APO:ARCPR_1207
# APO:ARCPR_1208
# APO:ARCPR_1209
# APO:ARCPR_1210
# APO:ARCPR_1211
# ...

# %%
from pandas import *
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

# %%
data = read_csv("SRB Analyst dataset-org.csv")
abr_name = data['Abbr_Name'].tolist()
organism_name = data['Organism name'].tolist()

# %%
#!rm -r $path$prem$deu$"/"$ess_fold
# Out:
# rm: it is dangerous to operate recursively on '/'
# rm: use --no-preserve-root to override this failsafe

# %%
path = "SRB_sequences/"
ess_fold = "Essential_Sequences"
for i in range(len(abr_name)-20):
    ###On cree un repertoire pour chaque organisme avec son son###
    val = organism_name[i]
    x = val.split()
    prem = x[0]+"_"
    deu = x[1]
    rep = prem+deu
    # !mkdir $path$prem$deu$"/"$ess_fold
       #load dataset
    #aa
    fastaSequences = SeqIO.parse(open("SRB_sequences/"+rep+"/SRB_"+abr_name[i]+"_aaseq_clean.fasta"), 'fasta')
    seqaaDict_E=dict()
    for fasta in fastaSequences:
      name, sequence = fasta.id, str(fasta.seq)
      seqaaDict_E[name]=sequence
    #print(seqaaDict_E)
    fastaSequences = SeqIO.parse(open("SRB_sequences/"+rep+"/SRB_"+abr_name[i]+"_aaseq_clean.fasta"), 'fasta')
    seqntDict_E=dict()
    for fasta in fastaSequences:
      name, sequence = fasta.id, str(fasta.seq)
      seqntDict_E[name]=sequence
    #print(seqntDict_E)
    index=0
    fileSeqAA=open("SRB_sequences/"+rep+"/Essential_Sequences"+"/SRB_"+abr_name[i]+"_EssentialsequenceAA-clean.fasta", 'a')
    fileSeqNT=open("SRB_sequences/"+rep+"/Essential_Sequences"+"/SRB_"+abr_name[i]+"_EssentialsequenceNT-clean.fasta", 'a')
    for cle in seqntDict_E.keys():
      if cle in seqaaDict_E:
        print(cle)
        sequenceProt=seqaaDict_E[cle].upper()
        sequenceGene=seqntDict_E[cle].upper()
        gene_Locus=cle
        recordAA=SeqRecord(Seq(sequenceProt), id=str(gene_Locus),description="")
        recordNT=SeqRecord(Seq(sequenceGene), id=str(gene_Locus),description="")
        SeqIO.write(recordAA, fileSeqAA, "fasta")
        SeqIO.write(recordNT, fileSeqNT, "fasta")
        index=index+1
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# DPR:DESPR_2272
# DPR:DESPR_2273
# DPR:DESPR_2274
# DPR:DESPR_2275
# DPR:DESPR_2276
# DPR:DESPR_2277
# DPR:DESPR_2278
# DPR:DESPR_2279
# DPR:DESPR_2280
# DPR:DESPR_2281
# DPR:DESPR_2282
# DPR:DESPR_2283
# DPR:DESPR_2284
# DPR:DESPR_2285
# DPR:DESPR_2286
# DPR:DESPR_2287
# DPR:DESPR_2288
# DPR:DESPR_2289
# DPR:DESPR_2290
# DPR:DESPR_2291
# DPR:DESPR_2293
# DPR:DESPR_2294
# DPR:DESPR_2295
# DPR:DESPR_2296
# DPR:DESPR_2297
# DPR:DESPR_2298
# DPR:DESPR_2299
# DPR:DESPR_2300
# DPR:DESPR_2301
# DPR:DESPR_2302
# DPR:DESPR_2303
# DPR:DESPR_2304
# DPR:DESPR_2305
# DPR:DESPR_2306
# DPR:DESPR_2307
# DPR:DESPR_2308
# DPR:DESPR_2309
# DPR:DESPR_2310
# DPR:DESPR_2311
# DPR:DESPR_2312
# DPR:DESPR_2313
# DPR:DESPR_2314
# DPR:DESPR_2315
# DPR:DESPR_2316
# DPR:DESPR_2317
# DPR:DESPR_2318
# DPR:DESPR_2319
# DPR:DESPR_2320
# DPR:DESPR_2321
# DPR:DESPR_2322
# DPR:DESPR_2323
# DPR:DESPR_2324
# DPR:DESPR_2325
# DPR:DESPR_2326
# ...
