# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
#
from matplotlib import pyplot as plt

# %%
feature_data = pd.read_csv("dti_Model_Score1.csv",sep=";")
feature_data = feature_data.replace(np.nan,0)
feature_data.drop(['#'], axis = 1, inplace = True) 
feature_data=feature_data.pivot_table(index="Feature", columns="Model", values=["Precison","Recall","F1_score","Roc_AUC"], aggfunc='mean')
#feature_data['DataFrame Column'] = feature_data['DataFrame Column'].astype(float)
#feature_data = feature_data.pivot("Feature","Organism","Roc_AUC")
#feature_data = feature_data.astype(float)
#feature_data.to_csv("data-dendrogram.csv")
feature_data
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# ...

# %%
ax = sns.heatmap(feature_data)

# %%
feature_data = pd.read_csv("/content/datatest.csv",sep=";")
feature_data = feature_data.replace(np.nan,0)
feature_data.drop(['#'], axis = 1, inplace = True) 
feature_data=feature_data.pivot_table(index="Feature", columns="Organism", values="Roc_AUC", aggfunc='first')
#feature_data['DataFrame Column'] = feature_data['DataFrame Column'].astype(float)
#feature_data = feature_data.pivot("Feature","Organism","Roc_AUC")
#feature_data = feature_data.astype(float)
feature_data.to_csv("data-dendrogram.csv")
feature_data

# %%
ax = sns.heatmap(feature_data)

# %%
flights = sns.load_dataset("flights")
#flights = flights.pivot("month", "year", "passengers")
flights

# %%
ax = sns.heatmap(flights)

# %%
feature_data = pd.read_csv("/content/HeatMaps-data.csv",sep=";")
feature_data = feature_data.replace(np.nan,0)
#feature_data['DataFrame Column'] = feature_data['DataFrame Column'].astype(float)
feature_data = feature_data.pivot("Feature","Model","Roc_AUC")
feature_data = feature_data.astype(float)
feature_data.to_csv("dataG20-dendrogram.csv")
feature_data
# Out:
# Model                           DEEP-HE  DEEP-SGS  DEEPLY  ...     DT     LR     RF
# Feature                                                    ...
# 89Deeply                          0.704     0.556   0.577  ...  0.734  0.717  0.857
# AAC                               0.000     0.593   0.615  ...  0.725  0.674  0.870
# APAAC                             0.000     0.562   0.526  ...  0.773  0.751  0.935
# Best100CTriad                     0.866     0.508   0.628  ...  0.708  0.648  0.934
# Best100Dipetide                   0.000     0.580   0.538  ...  0.700  0.609  0.947
# Best100GEARY                      0.000     0.504   0.500  ...  0.670  0.644  0.938
# Best100Moran                      0.000     0.473   0.423  ...  0.708  0.665  0.891
# Best100Moreau                     0.000     0.535   0.551  ...  0.742  0.712  0.920
# Best100Nucleotide                 0.756     0.567   0.603  ...  0.712  0.682  0.904
# ...

# %%
#ax = sns.heatmap(feature_data, annot=True, fmt="d")
ax = sns.heatmap(feature_data, annot=False)

# %%
feature_data = pd.read_csv("/content/HeatMaps-data.csv",sep=";")
feature_data = feature_data.replace(np.nan,0)
#feature_data['DataFrame Column'] = feature_data['DataFrame Column'].astype(float)
feature_data = feature_data.pivot("Model","Feature","Roc_AUC")
feature_data = feature_data.astype(float)
feature_data
ax = sns.heatmap(feature_data, annot=False)

# %%
# Data set
url = '/content/dendrogramData.csv'
df = pd.read_csv(url,sep=";")
df = df.replace(np.nan,0)
df = df.set_index('Feature')
model= df.pop("Model")
print(model)
df
# Out:
# Feature
# 89Deeply          DLM
# PAAC              DLM
# Best50SOCN        DLM
# Moran             DLM
# Moreau            DLM
#                ...
# Best50PAAC    DEEP-HE
# CTDD          DEEP-HE
# PseDNC        DEEP-HE
# CTDC          DEEP-HE
# ProtNT        DEEP-HE
# Name: Model, Length: 336, dtype: object
#             Precison  Recall  Roc_AUC
# Feature
# 89Deeply       0.904   0.829    0.850
# PAAC           0.791   0.778    0.777
# Best50SOCN     0.542   0.000    0.000
# Moran          0.872   0.859    0.850
# Moreau         0.832   0.696    0.790
# ...              ...     ...      ...
# Best50PAAC     0.563   0.028    0.880
# CTDD           0.530   0.000    0.000
# PseDNC         0.576   0.034    0.904
# CTDC           0.554   0.000    0.000
# ProtNT         0.581   0.026    0.859
#
# [336 rows x 3 columns]

# %%
# Prepare a vector of color mapped to the 'cyl' column
#my_palette = dict(zip(df.Model.unique(), ["orange","yellow","brown","blue","black","green","red"]))
lut = dict(zip(model.unique(), ["orange","aqua","brown","blue","fuchsia","green","purple"])) #"rbg"
row_colors =model.map(lut)
#print(lut)
# plot
graph=sns.clustermap(df,figsize=(14, 11), row_colors=row_colors)
for key, values in lut.items():
  graph.ax_col_dendrogram.bar(0, 0, color=values,
                            label=key, linewidth=0)
graph.ax_col_dendrogram.legend(loc="right", ncol=1)
#sns.clustermap(df, metric="correlation", method="single", cmap="Blues", standard_scale=1, row_colors=row_colors)  cmap="mako", vmin=0, vmax=10
#figsize=(7, 15), row_cluster=False, dendrogram_ratio=(.1, .2), cbar_pos=(0, .2, .03, .4)
plt.show()

# %%
url = '/content/mtcars.csv'
df = pd.read_csv(url)
df = df.replace(np.nan,0)
df
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
# library
import matplotlib.pyplot as plt
df = pd.read_csv("/content/FeatureGeneration-Number-Full.csv",sep=";")
#plt.rcParams["figure.figsize"] = (25,15)
# create random data
#names='groupA', 'groupB', 'groupC', 'groupD'
names=df['Feature']
values=df['#features']
 
# Create a pieplot
plt.pie(len(names))
# Label distance: gives the space between labels and the center of the pie
plt.pie(values, labels=names, labeldistance=1.05);
plt.show();

# %%
df = pd.read_csv("/content/FeatureGeneration-Number-Full-TC-Other.csv",sep=",")
labels=df['Feature']
sizes=df['#features']

explode=list()
explode.append(0.2)
count=len(sizes)-1
for i in range(count): 
  explode.append(0)

#plt.pie(sizes, labels = labels,startangle = 90,explode = explode,autopct='%1.1f%%',figsize=(6, 5))
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
#explode = (len(sizes))
fig1, ax1 = plt.subplots(figsize=(20, 20))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,explode = explode)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.legend(title = "Feature Group")
plt.show()

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("/content/FeatureGeneration-Number-Full-TC-Other.csv",sep=";")
labels=df['Feature']
sizes=df['#features']
explode = (0.2, 0)
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
#explode = (len(sizes))
fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,explode = explode)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df = pd.read_csv("/content/FeatureGeneration-Number-Full-other.csv",sep=";")
labels=df['Feature']
sizes=df['#features']

explode=list()
explode.append(0.2)
count=len(sizes)-1
for i in range(count): 
  explode.append(0)

#plt.pie(sizes, labels = labels,startangle = 90,explode = explode,autopct='%1.1f%%',figsize=(6, 5))
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
#explode = (len(sizes))
fig1, ax1 = plt.subplots(figsize=(20, 20))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,explode = explode)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.legend(title = "Feature Group")
plt.show()

# %%
#!pip install squarify

# libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd

# Create a data frame with fake data
df = pd.read_csv("/content/FeatureGeneration-Number-Full-other.csv",sep=";")
#
fig = plt.gcf()
fig.set_size_inches(20, 15)

fig = plt.gcf()
fig.set_size_inches(20, 15)

# plot it
squarify.plot(sizes=df['#features'], label=df['Feature'], alpha=.8)
plt.title("Feature Repartition")
plt.axis('off')
plt.show()
