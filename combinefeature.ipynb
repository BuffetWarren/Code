# %%
cd /home/billdjomkam/Bureau/Final work/Features_collections
# Out:
# /home/billdjomkam/Bureau/Final work/Features_collections

# %%
import pandas as pd
import os 
from os import listdir

# %%
path = "./"

# %%
#Bloc proteins
code_ct = "combineCTDC_CTDD_CTDT.R"
code_aac = "combineAAC_PAAC.R"
ctdc = "EssentialFeature_collection_CTDC.csv"
ctdd = "EssentialFeature_collection_CTDD.csv"
ctdt = "EssentialFeature_collection_CTDT.csv"
aac = "EssentialFeature_collection_AAC.csv"
paac = "EssentialFeature_collection_PAAC.csv"

#Bloc genes
code_daac = "combineDAAC_DCC.R"
code_taac = "combineTACC_TCC.R"
daac = "EssentialFeature_collection_DACC.csv"
dcc = "EssentialFeature_collection_DCC.csv"
tacc = "EssentialFeature_collection_TACC.csv"
tcc = "EssentialFeature_collection_TCC.csv"

#CodonW
code_codonw = "extractcodonw.R"
gene_file = "EssentialFeature_collection_Nucleotide.csv"

# %%
for f in os.listdir(path):
    #print(path+"/"+f)
    if os.path.isdir(path+f):
        for ls in os.listdir(path+f):
            spath = path+f+"/"+ls+"/"
            if ls =="subgroup_protein":
                print(spath)
                # !cp $code_ct $spath
                # !cp $code_aac $spath
                # %cd $spath
                # !Rscript $code_ct $ctdc $ctdd $ctdt
                # !Rscript $code_aac $aac $paac
                # !rm $code_ct $code_aac
                # %cd ../../
                
            else:
                print(spath)
                # !cp $code_daac $spath
                # !cp $code_taac $spath
                # %cd $spath
                # !Rscript $code_daac $daac $dcc
                # !Rscript $code_taac $tacc $tcc
                # !rm $code_daac $code_taac
                # %cd ../../

# %%
for i in os.listdir(path):
    #print(path+"/"+f)
    if os.path.isdir(path+i):
        for ls in os.listdir(path+i):
            spath = path+i+"/"+ls+"/"
            if ls =="subgroup_gene":
                print(spath)
                # !cp $code_codonw $spath
                # %cd $spath
                # !Rscript $code_codonw $gene_file
                # !rm $code_codonw
                # %cd ../../
# Out:
# ./daf_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/daf_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dti_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dti_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dsa_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dsa_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./apo_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/apo_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dde_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dde_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dml_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dml_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dru_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dru_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./tcm_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/tcm_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./doa_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/doa_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dae_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dae_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dpg_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dpg_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./top_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/top_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dfg_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dfg_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./drm_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/drm_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dpr_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dpr_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./ave_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/ave_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dpi_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dpi_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dgi_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dgi_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./ast_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/ast_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dgg_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dgg_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dma_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dma_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dba_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dba_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dca_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dca_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dhy_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dhy_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
# ./dku_Feature_collection/subgroup_gene/
# /home/billdjomkam/Bureau/Final work/Features_collections/dku_Feature_collection/subgroup_gene
#
# Attachement du package : ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# /home/billdjomkam/Bureau/Final work/Features_collections
